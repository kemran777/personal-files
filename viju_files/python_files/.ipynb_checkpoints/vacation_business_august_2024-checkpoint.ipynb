# %%
from sqlalchemy import create_engine
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from datetime import datetime, date, timedelta
pd.set_option('display.max_rows', 70)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

pd.set_option('display.max_columns', None)


pos = create_engine("postgresql+psycopg2://product_x_ro:9sNDZKJM5taKHfKZsoFvQMsMbtgSef@rc1a-yiz11yr42igms5a6.mdb.yandexcloud.net:6432/product_x")
pos.connect()


al = create_engine("clickhouse://superset:FmnaRL3cC6wnTkn@10.129.11.136:8123/superset")
al.connect()

# %% [markdown]
# # Marketing

# %% [markdown]
# ### Коллеги, доброе утро
# Сделайте , пожалуйста, выгрузки с 22 по 31 июля
#
# 1) Perfluence (по маскам карт, телефонам, почты, IP)
# — Perfluence 3 мес 399 \ 45 дней
# — Perfluence SPLASH за период
#
# 2) RIS (по маскам карт)
# — RIS (35 дней за 1 рубль)
#
# 3) Get4Click (по маскам карт)
# — Get4Click 29 rub month
# - Get4Click 30 days

# %%
df = pd.read_sql('''
--
                 select
                    *
                 from datamarts.marketing_dash_distr
                 where 
                  (
                     bonus_title ilike '%%perfluence%%'
                  or
                     bonus_title ilike '%%ris%%'
                  or
                     bonus_title ilike '%%get4click%%'
                  )
                 and 
                  created_at::date between '2024-08-06' and '2024-08-11'
                  ''', con=al)
df
# Out:
#                                   user_id  \
# 0    8e12cde4-a52a-41fb-ae9f-a023fda57cc7
# 1    a036b97b-a523-440f-8349-b6c34b30c3be
# 2    30082c01-4475-4383-8233-960ec90d31f8
# 3    92a72881-46a2-4e4c-853a-2669df8dc672
# 4    39214c8a-3e39-4d6b-86bd-84218ca38a04
# ..                                    ...
# 239  368fd0b1-82d8-468d-a2b8-54abe1ec80b3
# 240  29f1d2be-053b-4ebc-ae0f-4a44f0eea3c4
# 241  4775af2e-2768-4249-bf04-899ad3538399
# 242  8f26a83f-61da-4d4b-bfa2-31a436644708
# 243  5ed4cc3c-6c98-4936-bfb0-5bd3b6ccd39e
#
#                                visitor_id  \
# 0    93deaf05-3f71-4eda-ad30-b9891e1c8b19
# 1    95d49800-db5e-42a9-918a-d7747abf14c4
# 2    63eaa0c6-55d7-445f-8455-5ae84707152d
# 3    8090e219-c094-4262-bc57-b7dc9bfc693c
# 4    9ddd5f6c-d9cd-40f5-b03b-6f1162f7c2e8
# ..                                    ...
# 239  174c8cad-4984-49c0-a586-72dbcb723fc4
# 240  97346524-40a2-4ae7-b152-4e9cb865e25c
# 241  896110b8-ae65-4d10-a696-f77e9a1b8993
# ...

# %%
cards = pd.read_sql(f'''select * from payment_methods where user_id in {str(tuple(df['user_id'].unique()))}''',con=pos)
cards
# Out:
#                                        id  \
# 0    e42ca1d5-5512-4dac-85a7-964b118c160b
# 1    e554b11d-a9b3-4020-8891-3ebd0db558e9
# 2    c9f1a809-2977-41da-a93e-21e96e038d6f
# 3    0ba3e48f-780d-40e1-9ebd-39d92f539dd6
# 4    ea48a651-449d-4401-9377-f4ad7f2a4e9f
# ..                                    ...
# 239  639f86c7-cde5-44c1-b2df-0219eb1c8d5a
# 240  318b432b-8e5b-4c50-9542-bb7177344b7f
# 241  d1b73ba0-2ed5-4a98-97df-f3be705b998e
# 242  b7daed55-e49c-457c-a1cd-d5aac7105c29
# 243  2b70ff82-3ffa-4d80-bf64-4b88064ab9fd
#
#                                   user_id payment_system_id  origin  \
# 0    016b9098-9e1f-4826-a860-8f7cda30d6dc              None       1
# 1    020803a0-8d21-40c9-b95b-d331fe1837af              None       1
# 2    02e0aeba-1596-4d81-842f-cd25c74517c5              None       1
# 3    03c26f14-ba76-4967-96a2-20ae28150cb2              None       1
# 4    043e2964-1c29-4d70-a023-c856bc97ebb6              None       1
# ...

# %%
emails = pd.read_sql(f'''select * from users where id in {str(tuple(df['user_id'].unique()))}''',con=pos)
emails
# Out:
#                                        id                       email  \
# 0    016b9098-9e1f-4826-a860-8f7cda30d6dc                        None
# 1    020803a0-8d21-40c9-b95b-d331fe1837af                        None
# 2    02e0aeba-1596-4d81-842f-cd25c74517c5                        None
# 3    03c26f14-ba76-4967-96a2-20ae28150cb2                        None
# 4    043e2964-1c29-4d70-a023-c856bc97ebb6      super.regin4@yandex.ru
# ..                                    ...                         ...
# 239  fa66e99a-7a2f-4676-884d-c9bc2f7b1de7                        None
# 240  fcf7aa5a-df3b-47dc-b8ea-0ffd80036a1c                        None
# 241  fdaa4355-9df1-40d6-940b-7f8cbcc59dea                        None
# 242  fe23f6ed-3e09-4cff-9664-ab5639792423  dim.a.vaganoff96@gmail.com
# 243  ff7cb247-fa87-4007-9d4f-c825d163074b                        None
#
#     phone_number           unconfirmed_email unconfirmed_phone_number  \
# ...

# %%
cards['user_id'] = cards['user_id'].astype(str)
res = pd.merge(df, cards[['user_id','masked_number','active']], how='left', on='user_id')
res
# Out:
#                                   user_id  \
# 0    8e12cde4-a52a-41fb-ae9f-a023fda57cc7
# 1    a036b97b-a523-440f-8349-b6c34b30c3be
# 2    30082c01-4475-4383-8233-960ec90d31f8
# 3    92a72881-46a2-4e4c-853a-2669df8dc672
# 4    39214c8a-3e39-4d6b-86bd-84218ca38a04
# ..                                    ...
# 239  368fd0b1-82d8-468d-a2b8-54abe1ec80b3
# 240  29f1d2be-053b-4ebc-ae0f-4a44f0eea3c4
# 241  4775af2e-2768-4249-bf04-899ad3538399
# 242  8f26a83f-61da-4d4b-bfa2-31a436644708
# 243  5ed4cc3c-6c98-4936-bfb0-5bd3b6ccd39e
#
#                                visitor_id  \
# 0    93deaf05-3f71-4eda-ad30-b9891e1c8b19
# 1    95d49800-db5e-42a9-918a-d7747abf14c4
# 2    63eaa0c6-55d7-445f-8455-5ae84707152d
# 3    8090e219-c094-4262-bc57-b7dc9bfc693c
# 4    9ddd5f6c-d9cd-40f5-b03b-6f1162f7c2e8
# ..                                    ...
# 239  174c8cad-4984-49c0-a586-72dbcb723fc4
# 240  97346524-40a2-4ae7-b152-4e9cb865e25c
# 241  896110b8-ae65-4d10-a696-f77e9a1b8993
# ...

# %%
emails['id'] = emails['id'].astype(str)
res2 = pd.merge(res, emails[['id','email','phone_number']], how='left',left_on='user_id',right_on='id')
res2 = res2.drop('id',axis=1)
df1 = pd.read_sql(f'''
--
                 select
                    user_id,
                    min(user_ip_v4) as ip
                 from superset.events_distr
                 where 
                    user_id in {str(tuple(df['user_id'].unique()))}
                  group by 1
 ''',con=al)
res3 = pd.merge(res2, df1, how='left', on='user_id')
res3.to_excel('perf_getblogger_get4click_ris_cards_mails_phones_ip_0608_1108.xlsx', index=False)

# %% [markdown]
# ### всем привет! @abrigosu дай, пожалуйста, выгрузку по перешедшим в подписку:
# Perfluence 3 мес 399 \ 45 дней
# Perfluence 3 мес 399 \ 40 дней
#
# в прошлый раз по 15 мая было, в этот давай 16 мая -- 11 июня

# %%
df = pd.read_sql('''
--
                 select
                    *
                 from datamarts.marketing_dash_distr
                 where 
                  payer = 1 
                  and first_prolong_date between '2024-05-16' and '2024-06-11' 
                  and bonus_title ilike '%%per%%3%%' 
                 ''',con=al)
df.to_excel('perfluence_payers_1605_11_06.xlsx',index=False)

# %%
df = pd.read_sql('''
                    SELECT  *
                    FROM datamarts.marketing_dash_distr
                    WHERE  first_prolong_date between '2024-07-09' and '2024-08-14' 
                    AND  bonus_title like '%GetBlogger%'
                    AND payer = 1 
                 ''',con=al)
df.to_excel('getbloggers_payers_0709_0814.xlsx',index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = pd.read_sql('''
#       2                     SELECT  *
#       3                     FROM datamarts.marketing_dash_distr
#       4                     WHERE  first_prolong_date between '2024-07-09' and '2024-08-14'
#       5                     AND  bonus_title like '%GetBlogger%'
#       6                     AND payer = 1
#       7                  ''',con=al)
#       8 df.to_excel('getbloggers_payers_0709_0814.xlsx',index=False)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:682, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     672     return pandas_sql.read_table(
#     673         sql,
#     674         index_col=index_col,
#    (...)
#     679         dtype_backend=dtype_backend,
#     680     )
# ...
