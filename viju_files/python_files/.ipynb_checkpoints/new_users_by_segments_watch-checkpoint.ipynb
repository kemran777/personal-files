# %%
import pandas as pd
import psycopg2
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import seaborn as sns 
import statsmodels .stats.proportion as proportion
from scipy.stats import ttest_ind,mannwhitneyu,shapiro,norm
from statsmodels.stats.weightstats import ztest
from tqdm import tqdm
import timeit
from scipy import stats
import math
from datetime import date, datetime, timedelta
import time
from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker
import warnings
warnings.filterwarnings("ignore")

from credential import postgres_secret,clickhouse_dwh_secret

def get_engine(user):
    if user == postgres_secret['user']:
        db_name = postgres_secret['db_name']
        password = postgres_secret['password']
        host = postgres_secret['host']
        engine = create_engine(f'postgresql://{user}:{password}@{host}:6432/{db_name}')
    elif user == clickhouse_dwh_secret['user']:
            db_name = clickhouse_dwh_secret['db_name'] 
            password = clickhouse_dwh_secret['password']
            host = clickhouse_dwh_secret['host']
            engine = create_engine(f'clickhouse://{user}:{password}@{host}:8123/{db_name}')
    return engine
    

    
def execute(SQL, user):
    start_time = time.time()  # запоминаем время начала выполнения функции
    engine = get_engine(user)
    Session = sessionmaker(bind=engine)  # sessions factory ()
    with Session() as session: # open session
        result = session.execute(text(SQL))
        df = pd.DataFrame(result.fetchall(), columns=result.keys())
        
    end_time = time.time()  # запоминаем время окончания выполнения функции
    execution_time = round(end_time - start_time,4) # вычисляем время выполнения   
    
    print(f"Время выполнения функции: {execution_time} секунд")
    print()
    return df

# %%
query = '''CREATE TABLE datamarts.mekhtiev_watchtime_analyse_local ON CLUSTER 'viasat_cluster'
            (
                date_week Date,
                user_id UUID,
                profile_id UUID,
                watchtime Int32,
                active_day Int32,
                watch_day Int32,
                viewing_cnt Int32,
                viewing_watch_cnt Int32
             )
             ENGINE = ReplicatedMergeTree('/clickhouse/tables/{shard}/datamarts.mekhtiev_watchtime_analyse_local', '{replica}')
             ORDER BY date_week
             '''
execute(query,user = 'kmekhtiev')

# %%
query = f'''CREATE TABLE datamarts.mekhtiev_watchtime_analyse_distr ON CLUSTER 'viasat_cluster'
            (
                date_week Date,
                user_id UUID,
                profile_id UUID,
                watchtime Int32,
                active_day Int32,
                watch_day Int32,
                viewing_cnt Int32,
                viewing_watch_cnt Int32
             )
             ENGINE = Distributed(viasat_cluster, datamarts, mekhtiev_watchtime_analyse_local, rand())
             '''
execute(query,user = 'kmekhtiev')

# %%
list_date = pd.date_range("2024-04-01", "2024-08-08", freq='D')
result = []
for date in list_date:
    date_str = date.strftime('%Y-%m-%d')
    query_delete = f" DELETE FROM datamarts.mekhtiev_watchtime_analyse_local  ON CLUSTER 'viasat_cluster' WHERE date_week = '{date}'::date"
    execute(query_delete,user = 'kmekhtiev')
    print(f'Дата {date_str} удалена из таблицы')
    query = f"""INSERT INTO datamarts.mekhtiev_watchtime_analyse_distr
                SELECT 
                t1.date_week,
                t1.user_id,
                t1.profile_id,
                t2.watchtime,
                t1.active_day,
                t2.watch_day,
                t2.viewing_cnt,
                t2.viewing_watch_cnt
                FROM 
                (SELECT
                                '{date_str}' AS date_week,
                                user_id,
                                profile_id,
                                uniq(date) as active_day
                                FROM
                                datamarts.sandbox_data_distr AS t1
                                LEFT JOIN product_x.users AS u ON t1.user_id=u.id
                                WHERE client_type!='backend' 
                                AND reg_date!='1970-01-01'
                                AND date BETWEEN '{date}'::date - interval '6' DAY AND '{date}'::date
                                AND profile_id IS NOT NULL  
                                AND (u.email NOT LIKE '%@test%' OR u.email IS NULL)
                                AND (promo_type IS NULL OR promo_type!='cards')
                                GROUP BY 1,2,3
                                ) AS t1

                    LEFT JOIN (SELECT 
                                 date_week,
                                 profile_id,
                                 viewing_cnt,
                                 viewing_watch_cnt,
                                 count(DISTINCT CASE WHEN viewing_time>30 THEN date END) AS watch_day,
                                 sum(viewing_time) AS watchtime
                                 FROM 
                                     (SELECT 
                                        date_week,
                                        date,
                                        profile_id,
                                        viewing_cnt,
                                        viewing_watch_cnt,
                                        COALESCE(sum(viewing_time),0) AS viewing_time
                                        FROM 
                                                    (SELECT 
                                                    date_week,
                                                    date,
                                                    profile_id,
                                                    item_type,
                                                    item_title,
                                                    viewing_time,
                                                    viewing_cnt,
                                                    COALESCE(count(DISTINCT CASE WHEN viewing_time_per_item>30 THEN item_title END) OVER (PARTITION BY date_week,profile_id),0) AS viewing_watch_cnt    
                                                    FROM  
                                                            (SELECT 
                                                             '{date_str}' AS date_week,
                                                            date,
                                                            profile_id,
                                                            event_name,
                                                            event_page,
                                                            u.email,
                                                            JSONExtractInt(payload,'duration') AS duration,
                                                            JSONExtractString(payload,'item_type') AS item_type,
                                                            JSONExtractString(payload,'item_title') AS item_title,
                                                            CASE WHEN event_page<>'tvchannel'
                                                                      AND JSONExtractInt(payload,'viewing_time')<= JSONExtractInt(payload,'duration') 
                                                                      THEN JSONExtractInt(payload,'viewing_time')
                                                                 WHEN event_page='tvchannel' 
                                                                      AND JSONExtractInt(payload,'viewing_time') <18000 
                                                                      THEN JSONExtractInt(payload,'viewing_time')
                                                            END AS viewing_time,
                                                            count(DISTINCT item_title) OVER (PARTITION BY date_week,profile_id) AS viewing_cnt,
                                                            sum(viewing_time) OVER (PARTITION BY date_week,profile_id,item_title) AS viewing_time_per_item                                      		 
                                                            FROM datamarts.sandbox_data_distr AS t1
                                                            LEFT JOIN product_x.users AS u ON t1.user_id=u.id
                                                            WHERE date BETWEEN '{date}'::date - interval '6' DAY AND '{date}'::date
                                                            AND event_name IN ('auto_player_streaming','auto_kinom_streaming')
                                                            AND viewing_time IS NOT NULL  
                                                            AND (promo_type IS NULL OR promo_type!='cards')
                                                             )
                                                        )
                                         GROUP BY 1,2,3,4,5
                                        )
                                     GROUP BY 1,2,3,4
                                     ) AS t2
                                     
        ON t1.date_week=t2.date_week
        AND t1.profile_id=t2.profile_id
        """
    df_temp = execute(query,user = 'kmekhtiev')   
    result.append(df_temp)
    print(f"""Дата '{date_str}' загружена""")
    print()

df = pd.concat(result)
# Out:
# Время выполнения функции: 0.908 секунд
#
# Дата 2024-04-01 удалена из таблицы
# Время выполнения функции: 11.562 секунд
#
# Дата '2024-04-01' загружена
#
# Время выполнения функции: 0.4581 секунд
#
# Дата 2024-04-02 удалена из таблицы
# Время выполнения функции: 13.2572 секунд
#
# Дата '2024-04-02' загружена
#
# Время выполнения функции: 0.345 секунд
#
# Дата 2024-04-03 удалена из таблицы
# Время выполнения функции: 13.2012 секунд
#
# Дата '2024-04-03' загружена
#
# Время выполнения функции: 1.4834 секунд
#
# Дата 2024-04-04 удалена из таблицы
# Время выполнения функции: 12.6231 секунд
#
# Дата '2024-04-04' загружена
#
# Время выполнения функции: 0.408 секунд
#
# Дата 2024-04-05 удалена из таблицы
# Время выполнения функции: 11.4012 секунд
#
# Дата '2024-04-05' загружена
#
# Время выполнения функции: 1.8267 секунд
#
# Дата 2024-04-06 удалена из таблицы
# Время выполнения функции: 12.729 секунд
#
# Дата '2024-04-06' загружена
#
# Время выполнения функции: 1.887 секунд
#
# Дата 2024-04-07 удалена из таблицы
# Время выполнения функции: 12.7567 секунд
#
# Дата '2024-04-07' загружена
#
# Время выполнения функции: 0.3591 секунд
#
# Дата 2024-04-08 удалена из таблицы
# Время выполнения функции: 11.5723 секунд
#
# Дата '2024-04-08' загружена
#
# Время выполнения функции: 2.1365 секунд
#
# Дата 2024-04-09 удалена из таблицы
# Время выполнения функции: 11.6766 секунд
#
# Дата '2024-04-09' загружена
#
# Время выполнения функции: 2.0395 секунд
#
# Дата 2024-04-10 удалена из таблицы
# Время выполнения функции: 11.5465 секунд
#
# Дата '2024-04-10' загружена
#
# Время выполнения функции: 2.3197 секунд
#
# Дата 2024-04-11 удалена из таблицы
# Время выполнения функции: 13.3871 секунд
#
# Дата '2024-04-11' загружена
#
# Время выполнения функции: 0.3371 секунд
#
# Дата 2024-04-12 удалена из таблицы
# Время выполнения функции: 11.4394 секунд
#
# Дата '2024-04-12' загружена
#
# Время выполнения функции: 2.3535 секунд
#
# Дата 2024-04-13 удалена из таблицы
# Время выполнения функции: 11.2132 секунд
#
# Дата '2024-04-13' загружена
#
# Время выполнения функции: 2.5649 секунд
#
# Дата 2024-04-14 удалена из таблицы
# Время выполнения функции: 13.0848 секунд
#
# Дата '2024-04-14' загружена
#
# Время выполнения функции: 0.5407 секунд
#
# Дата 2024-04-15 удалена из таблицы
# Время выполнения функции: 13.1614 секунд
#
# Дата '2024-04-15' загружена
#
# Время выполнения функции: 0.3224 секунд
#
# Дата 2024-04-16 удалена из таблицы
# Время выполнения функции: 13.5311 секунд
#
# Дата '2024-04-16' загружена
#
# Время выполнения функции: 0.7311 секунд
#
# Дата 2024-04-17 удалена из таблицы
# Время выполнения функции: 13.0994 секунд
#
# Дата '2024-04-17' загружена
#
# Время выполнения функции: 0.3312 секунд
#
# Дата 2024-04-18 удалена из таблицы
# Время выполнения функции: 11.6119 секунд
#
# Дата '2024-04-18' загружена
#
# Время выполнения функции: 1.8348 секунд
#
# Дата 2024-04-19 удалена из таблицы
# Время выполнения функции: 11.3062 секунд
#
# Дата '2024-04-19' загружена
#
# Время выполнения функции: 2.4826 секунд
#
# Дата 2024-04-20 удалена из таблицы
# Время выполнения функции: 11.123 секунд
#
# Дата '2024-04-20' загружена
#
# Время выполнения функции: 2.6975 секунд
#
# Дата 2024-04-21 удалена из таблицы
# Время выполнения функции: 11.6107 секунд
#
# Дата '2024-04-21' загружена
#
# Время выполнения функции: 2.0663 секунд
#
# Дата 2024-04-22 удалена из таблицы
# Время выполнения функции: 11.7839 секунд
#
# Дата '2024-04-22' загружена
#
# Время выполнения функции: 1.9819 секунд
#
# Дата 2024-04-23 удалена из таблицы
# Время выполнения функции: 11.6618 секунд
#
# Дата '2024-04-23' загружена
#
# Время выполнения функции: 2.2863 секунд
#
# Дата 2024-04-24 удалена из таблицы
# Время выполнения функции: 11.8151 секунд
#
# Дата '2024-04-24' загружена
#
# Время выполнения функции: 1.8289 секунд
#
# Дата 2024-04-25 удалена из таблицы
# Время выполнения функции: 11.7274 секунд
#
# Дата '2024-04-25' загружена
#
# Время выполнения функции: 2.3895 секунд
#
# Дата 2024-04-26 удалена из таблицы
# Время выполнения функции: 12.6401 секунд
#
# Дата '2024-04-26' загружена
#
# Время выполнения функции: 0.7432 секунд
#
# Дата 2024-04-27 удалена из таблицы
# Время выполнения функции: 12.9624 секунд
#
# Дата '2024-04-27' загружена
#
# Время выполнения функции: 0.7986 секунд
#
# Дата 2024-04-28 удалена из таблицы
# Время выполнения функции: 12.5856 секунд
#
# Дата '2024-04-28' загружена
#
# Время выполнения функции: 1.2117 секунд
#
# Дата 2024-04-29 удалена из таблицы
# Время выполнения функции: 12.2742 секунд
#
# Дата '2024-04-29' загружена
#
# Время выполнения функции: 1.4846 секунд
#
# Дата 2024-04-30 удалена из таблицы
# Время выполнения функции: 11.9699 секунд
#
# Дата '2024-04-30' загружена
#
# Время выполнения функции: 1.4716 секунд
#
# Дата 2024-05-01 удалена из таблицы
# Время выполнения функции: 11.8617 секунд
#
# Дата '2024-05-01' загружена
#
# Время выполнения функции: 2.5278 секунд
#
# Дата 2024-05-02 удалена из таблицы
# Время выполнения функции: 12.0922 секунд
#
# Дата '2024-05-02' загружена
#
# Время выполнения функции: 1.2888 секунд
#
# Дата 2024-05-03 удалена из таблицы
# Время выполнения функции: 14.1597 секунд
#
# Дата '2024-05-03' загружена
#
# Время выполнения функции: 1.0897 секунд
#
# Дата 2024-05-04 удалена из таблицы
# Время выполнения функции: 10.7852 секунд
#
# Дата '2024-05-04' загружена
#
# Время выполнения функции: 2.259 секунд
#
# Дата 2024-05-05 удалена из таблицы
# Время выполнения функции: 10.6022 секунд
#
# Дата '2024-05-05' загружена
#
# Время выполнения функции: 3.0326 секунд
#
# Дата 2024-05-06 удалена из таблицы
# Время выполнения функции: 10.7993 секунд
#
# Дата '2024-05-06' загружена
#
# Время выполнения функции: 2.6149 секунд
#
# Дата 2024-05-07 удалена из таблицы
# Время выполнения функции: 10.6506 секунд
#
# Дата '2024-05-07' загружена
#
# Время выполнения функции: 0.4253 секунд
#
# Дата 2024-05-08 удалена из таблицы
# Время выполнения функции: 10.8227 секунд
#
# Дата '2024-05-08' загружена
#
# Время выполнения функции: 0.3801 секунд
#
# Дата 2024-05-09 удалена из таблицы
# Время выполнения функции: 9.226 секунд
#
# Дата '2024-05-09' загружена
#
# Время выполнения функции: 3.0828 секунд
#
# Дата 2024-05-10 удалена из таблицы
# Время выполнения функции: 10.555 секунд
#
# Дата '2024-05-10' загружена
#
# Время выполнения функции: 0.3651 секунд
#
# Дата 2024-05-11 удалена из таблицы
# Время выполнения функции: 10.9953 секунд
#
# Дата '2024-05-11' загружена
#
# Время выполнения функции: 0.372 секунд
#
# Дата 2024-05-12 удалена из таблицы
# Время выполнения функции: 10.4334 секунд
#
# Дата '2024-05-12' загружена
#
# Время выполнения функции: 2.1599 секунд
#
# Дата 2024-05-13 удалена из таблицы
# Время выполнения функции: 10.8597 секунд
#
# Дата '2024-05-13' загружена
#
# Время выполнения функции: 0.4263 секунд
#
# Дата 2024-05-14 удалена из таблицы
# Время выполнения функции: 10.6205 секунд
#
# Дата '2024-05-14' загружена
#
# Время выполнения функции: 1.6665 секунд
#
# Дата 2024-05-15 удалена из таблицы
# Время выполнения функции: 9.2251 секунд
#
# Дата '2024-05-15' загружена
#
# Время выполнения функции: 3.1884 секунд
#
# Дата 2024-05-16 удалена из таблицы
# Время выполнения функции: 10.7334 секунд
#
# Дата '2024-05-16' загружена
#
# Время выполнения функции: 2.3147 секунд
#
# Дата 2024-05-17 удалена из таблицы
# Время выполнения функции: 11.2534 секунд
#
# Дата '2024-05-17' загружена
#
# Время выполнения функции: 1.851 секунд
#
# Дата 2024-05-18 удалена из таблицы
# Время выполнения функции: 11.3326 секунд
#
# Дата '2024-05-18' загружена
#
# Время выполнения функции: 2.3649 секунд
#
# Дата 2024-05-19 удалена из таблицы
# Время выполнения функции: 11.3314 секунд
#
# Дата '2024-05-19' загружена
#
# Время выполнения функции: 2.1137 секунд
#
# Дата 2024-05-20 удалена из таблицы
# Время выполнения функции: 13.9914 секунд
#
# Дата '2024-05-20' загружена
#
# Время выполнения функции: 0.3054 секунд
#
# Дата 2024-05-21 удалена из таблицы
# Время выполнения функции: 28.4508 секунд
#
# Дата '2024-05-21' загружена
#
# Время выполнения функции: 0.2945 секунд
#
# Дата 2024-05-22 удалена из таблицы
# Время выполнения функции: 21.6223 секунд
#
# Дата '2024-05-22' загружена
#
# Время выполнения функции: 0.4518 секунд
#
# Дата 2024-05-23 удалена из таблицы
# Время выполнения функции: 18.3407 секунд
#
# Дата '2024-05-23' загружена
#
# Время выполнения функции: 0.6576 секунд
#
# Дата 2024-05-24 удалена из таблицы
# Время выполнения функции: 14.0534 секунд
#
# Дата '2024-05-24' загружена
#
# Время выполнения функции: 0.3201 секунд
#
# Дата 2024-05-25 удалена из таблицы
# Время выполнения функции: 14.7511 секунд
#
# Дата '2024-05-25' загружена
#
# Время выполнения функции: 1.4973 секунд
#
# Дата 2024-05-26 удалена из таблицы
# Время выполнения функции: 25.1894 секунд
#
# Дата '2024-05-26' загружена
#
# Время выполнения функции: 0.7193 секунд
#
# Дата 2024-05-27 удалена из таблицы
# Время выполнения функции: 13.9473 секунд
#
# Дата '2024-05-27' загружена
#
# Время выполнения функции: 2.0536 секунд
#
# Дата 2024-05-28 удалена из таблицы
# Время выполнения функции: 16.1026 секунд
#
# Дата '2024-05-28' загружена
#
# Время выполнения функции: 0.4623 секунд
#
# Дата 2024-05-29 удалена из таблицы
# Время выполнения функции: 17.8 секунд
#
# Дата '2024-05-29' загружена
#
# Время выполнения функции: 1.9263 секунд
#
# Дата 2024-05-30 удалена из таблицы
# Время выполнения функции: 15.1591 секунд
#
# Дата '2024-05-30' загружена
#
# Время выполнения функции: 0.3049 секунд
#
# Дата 2024-05-31 удалена из таблицы
# Время выполнения функции: 17.6617 секунд
#
# Дата '2024-05-31' загружена
#
# Время выполнения функции: 0.414 секунд
#
# Дата 2024-06-01 удалена из таблицы
# Время выполнения функции: 13.3952 секунд
#
# Дата '2024-06-01' загружена
#
# Время выполнения функции: 0.4261 секунд
#
# Дата 2024-06-02 удалена из таблицы
# Время выполнения функции: 19.6322 секунд
#
# Дата '2024-06-02' загружена
#
# Время выполнения функции: 2.1168 секунд
#
# Дата 2024-06-03 удалена из таблицы
# Время выполнения функции: 21.6815 секунд
#
# Дата '2024-06-03' загружена
#
# Время выполнения функции: 1.7117 секунд
#
# Дата 2024-06-04 удалена из таблицы
# Время выполнения функции: 19.6551 секунд
#
# Дата '2024-06-04' загружена
#
# Время выполнения функции: 0.3578 секунд
#
# Дата 2024-06-05 удалена из таблицы
# Время выполнения функции: 18.3423 секунд
#
# Дата '2024-06-05' загружена
#
# Время выполнения функции: 0.4137 секунд
#
# Дата 2024-06-06 удалена из таблицы
# Время выполнения функции: 26.8938 секунд
#
# Дата '2024-06-06' загружена
#
# Время выполнения функции: 1.1139 секунд
#
# Дата 2024-06-07 удалена из таблицы
# Время выполнения функции: 14.9726 секунд
#
# Дата '2024-06-07' загружена
#
# Время выполнения функции: 0.4222 секунд
#
# Дата 2024-06-08 удалена из таблицы
# Время выполнения функции: 14.8818 секунд
#
# Дата '2024-06-08' загружена
#
# Время выполнения функции: 2.748 секунд
#
# Дата 2024-06-09 удалена из таблицы
# Время выполнения функции: 17.9685 секунд
#
# Дата '2024-06-09' загружена
#
# Время выполнения функции: 3.2177 секунд
#
# Дата 2024-06-10 удалена из таблицы
# Время выполнения функции: 13.1438 секунд
#
# Дата '2024-06-10' загружена
#
# Время выполнения функции: 0.933 секунд
#
# Дата 2024-06-11 удалена из таблицы
# Время выполнения функции: 14.328 секунд
#
# Дата '2024-06-11' загружена
#
# Время выполнения функции: 1.4407 секунд
#
# Дата 2024-06-12 удалена из таблицы
# Время выполнения функции: 15.9794 секунд
#
# Дата '2024-06-12' загружена
#
# Время выполнения функции: 0.3111 секунд
#
# Дата 2024-06-13 удалена из таблицы
# Время выполнения функции: 14.6129 секунд
#
# Дата '2024-06-13' загружена
#
# Время выполнения функции: 2.5424 секунд
#
# Дата 2024-06-14 удалена из таблицы
# Время выполнения функции: 14.9954 секунд
#
# Дата '2024-06-14' загружена
#
# Время выполнения функции: 0.4139 секунд
#
# Дата 2024-06-15 удалена из таблицы
# Время выполнения функции: 22.0329 секунд
#
# Дата '2024-06-15' загружена
#
# Время выполнения функции: 0.4172 секунд
#
# Дата 2024-06-16 удалена из таблицы
# Время выполнения функции: 16.4867 секунд
#
# Дата '2024-06-16' загружена
#
# Время выполнения функции: 0.9215 секунд
#
# Дата 2024-06-17 удалена из таблицы
# Время выполнения функции: 12.2906 секунд
#
# Дата '2024-06-17' загружена
#
# Время выполнения функции: 1.1516 секунд
#
# Дата 2024-06-18 удалена из таблицы
# Время выполнения функции: 14.9231 секунд
#
# Дата '2024-06-18' загружена
#
# Время выполнения функции: 0.3736 секунд
#
# Дата 2024-06-19 удалена из таблицы
# Время выполнения функции: 16.0635 секунд
#
# Дата '2024-06-19' загружена
#
# Время выполнения функции: 0.365 секунд
#
# Дата 2024-06-20 удалена из таблицы
# Время выполнения функции: 15.8549 секунд
#
# Дата '2024-06-20' загружена
#
# Время выполнения функции: 1.1488 секунд
#
# Дата 2024-06-21 удалена из таблицы
# Время выполнения функции: 36.1694 секунд
#
# Дата '2024-06-21' загружена
#
# Время выполнения функции: 0.4748 секунд
#
# Дата 2024-06-22 удалена из таблицы
# Время выполнения функции: 17.1814 секунд
#
# Дата '2024-06-22' загружена
#
# Время выполнения функции: 1.3451 секунд
#
# Дата 2024-06-23 удалена из таблицы
# Время выполнения функции: 15.4203 секунд
#
# Дата '2024-06-23' загружена
#
# Время выполнения функции: 0.3338 секунд
#
# Дата 2024-06-24 удалена из таблицы
# Время выполнения функции: 30.4575 секунд
#
# Дата '2024-06-24' загружена
#
# Время выполнения функции: 0.4637 секунд
#
# Дата 2024-06-25 удалена из таблицы
# Время выполнения функции: 13.5116 секунд
#
# Дата '2024-06-25' загружена
#
# Время выполнения функции: 0.4532 секунд
#
# Дата 2024-06-26 удалена из таблицы
# Время выполнения функции: 13.1288 секунд
#
# Дата '2024-06-26' загружена
#
# Время выполнения функции: 0.4292 секунд
#
# Дата 2024-06-27 удалена из таблицы
# Время выполнения функции: 14.7173 секунд
#
# Дата '2024-06-27' загружена
#
# Время выполнения функции: 1.8497 секунд
#
# Дата 2024-06-28 удалена из таблицы
# Время выполнения функции: 14.6158 секунд
#
# Дата '2024-06-28' загружена
#
# Время выполнения функции: 2.0147 секунд
#
# Дата 2024-06-29 удалена из таблицы
# Время выполнения функции: 14.4801 секунд
#
# Дата '2024-06-29' загружена
#
# Время выполнения функции: 2.1219 секунд
#
# Дата 2024-06-30 удалена из таблицы
# Время выполнения функции: 41.7088 секунд
#
# Дата '2024-06-30' загружена
#
# Время выполнения функции: 0.5274 секунд
#
# Дата 2024-07-01 удалена из таблицы
# Время выполнения функции: 12.254 секунд
#
# Дата '2024-07-01' загружена
#
# Время выполнения функции: 0.4395 секунд
#
# Дата 2024-07-02 удалена из таблицы
# Время выполнения функции: 11.0745 секунд
#
# Дата '2024-07-02' загружена
#
# Время выполнения функции: 1.15 секунд
#
# Дата 2024-07-03 удалена из таблицы
# Время выполнения функции: 8.9159 секунд
#
# Дата '2024-07-03' загружена
#
# Время выполнения функции: 0.3665 секунд
#
# Дата 2024-07-04 удалена из таблицы
# Время выполнения функции: 10.6031 секунд
#
# Дата '2024-07-04' загружена
#
# Время выполнения функции: 0.5407 секунд
#
# Дата 2024-07-05 удалена из таблицы
# Время выполнения функции: 11.0334 секунд
#
# Дата '2024-07-05' загружена
#
# Время выполнения функции: 1.7903 секунд
#
# Дата 2024-07-06 удалена из таблицы
# Время выполнения функции: 11.6129 секунд
#
# Дата '2024-07-06' загружена
#
# Время выполнения функции: 3.1032 секунд
#
# Дата 2024-07-07 удалена из таблицы
# Время выполнения функции: 12.5606 секунд
#
# Дата '2024-07-07' загружена
#
# Время выполнения функции: 0.5029 секунд
#
# Дата 2024-07-08 удалена из таблицы
# Время выполнения функции: 12.5853 секунд
#
# Дата '2024-07-08' загружена
#
# Время выполнения функции: 1.0974 секунд
#
# Дата 2024-07-09 удалена из таблицы
# Время выполнения функции: 11.797 секунд
#
# Дата '2024-07-09' загружена
#
# Время выполнения функции: 2.0211 секунд
#
# Дата 2024-07-10 удалена из таблицы
# Время выполнения функции: 11.6337 секунд
#
# Дата '2024-07-10' загружена
#
# Время выполнения функции: 2.1921 секунд
#
# Дата 2024-07-11 удалена из таблицы
# Время выполнения функции: 11.6668 секунд
#
# Дата '2024-07-11' загружена
#
# Время выполнения функции: 2.3589 секунд
#
# Дата 2024-07-12 удалена из таблицы
# Время выполнения функции: 11.7015 секунд
#
# Дата '2024-07-12' загружена
#
# Время выполнения функции: 3.5063 секунд
#
# Дата 2024-07-13 удалена из таблицы
# Время выполнения функции: 13.1963 секунд
#
# Дата '2024-07-13' загружена
#
# Время выполнения функции: 0.3711 секунд
#
# Дата 2024-07-14 удалена из таблицы
# Время выполнения функции: 13.1683 секунд
#
# Дата '2024-07-14' загружена
#
# Время выполнения функции: 0.3272 секунд
#
# Дата 2024-07-15 удалена из таблицы
# Время выполнения функции: 11.4977 секунд
#
# Дата '2024-07-15' загружена
#
# Время выполнения функции: 1.7303 секунд
#
# Дата 2024-07-16 удалена из таблицы
# Время выполнения функции: 11.5051 секунд
#
# Дата '2024-07-16' загружена
#
# Время выполнения функции: 2.1555 секунд
#
# Дата 2024-07-17 удалена из таблицы
# Время выполнения функции: 7.1052 секунд
#
# Дата '2024-07-17' загружена
#
# Время выполнения функции: 0.3404 секунд
#
# Дата 2024-07-18 удалена из таблицы
# Время выполнения функции: 7.1342 секунд
#
# Дата '2024-07-18' загружена
#
# Время выполнения функции: 0.4048 секунд
#
# Дата 2024-07-19 удалена из таблицы
# Время выполнения функции: 7.1432 секунд
#
# Дата '2024-07-19' загружена
#
# Время выполнения функции: 0.343 секунд
#
# Дата 2024-07-20 удалена из таблицы
# Время выполнения функции: 7.1811 секунд
#
# Дата '2024-07-20' загружена
#
# Время выполнения функции: 0.3348 секунд
#
# Дата 2024-07-21 удалена из таблицы
# Время выполнения функции: 7.0807 секунд
#
# Дата '2024-07-21' загружена
#
# Время выполнения функции: 0.3665 секунд
#
# Дата 2024-07-22 удалена из таблицы
# Время выполнения функции: 7.0919 секунд
#
# Дата '2024-07-22' загружена
#
# Время выполнения функции: 0.3495 секунд
#
# Дата 2024-07-23 удалена из таблицы
# Время выполнения функции: 6.9833 секунд
#
# Дата '2024-07-23' загружена
#
# Время выполнения функции: 0.2952 секунд
#
# Дата 2024-07-24 удалена из таблицы
# Время выполнения функции: 7.3954 секунд
#
# Дата '2024-07-24' загружена
#
# Время выполнения функции: 0.364 секунд
#
# Дата 2024-07-25 удалена из таблицы
# Время выполнения функции: 7.045 секунд
#
# Дата '2024-07-25' загружена
#
# Время выполнения функции: 2.1084 секунд
#
# Дата 2024-07-26 удалена из таблицы
# Время выполнения функции: 7.17 секунд
#
# Дата '2024-07-26' загружена
#
# Время выполнения функции: 0.3409 секунд
#
# Дата 2024-07-27 удалена из таблицы
# Время выполнения функции: 6.9256 секунд
#
# Дата '2024-07-27' загружена
#
# Время выполнения функции: 0.3866 секунд
#
# Дата 2024-07-28 удалена из таблицы
# Время выполнения функции: 7.0757 секунд
#
# Дата '2024-07-28' загружена
#
# Время выполнения функции: 0.3335 секунд
#
# Дата 2024-07-29 удалена из таблицы
# Время выполнения функции: 7.4955 секунд
#
# Дата '2024-07-29' загружена
#
# Время выполнения функции: 0.337 секунд
#
# Дата 2024-07-30 удалена из таблицы
# Время выполнения функции: 7.1184 секунд
#
# Дата '2024-07-30' загружена
#
# Время выполнения функции: 0.3432 секунд
#
# Дата 2024-07-31 удалена из таблицы
# Время выполнения функции: 7.1318 секунд
#
# Дата '2024-07-31' загружена
#
# Время выполнения функции: 0.335 секунд
#
# Дата 2024-08-01 удалена из таблицы
# Время выполнения функции: 6.9129 секунд
#
# Дата '2024-08-01' загружена
#
# Время выполнения функции: 3.0283 секунд
#
# Дата 2024-08-02 удалена из таблицы
# Время выполнения функции: 7.4065 секунд
#
# Дата '2024-08-02' загружена
#
# Время выполнения функции: 0.3353 секунд
#
# Дата 2024-08-03 удалена из таблицы
# Время выполнения функции: 7.0343 секунд
#
# Дата '2024-08-03' загружена
#
# Время выполнения функции: 0.3313 секунд
#
# Дата 2024-08-04 удалена из таблицы
# Время выполнения функции: 7.0474 секунд
#
# Дата '2024-08-04' загружена
#
# Время выполнения функции: 0.338 секунд
#
# Дата 2024-08-05 удалена из таблицы
# Время выполнения функции: 7.1209 секунд
#
# Дата '2024-08-05' загружена
#
# Время выполнения функции: 1.0606 секунд
#
# Дата 2024-08-06 удалена из таблицы
# Время выполнения функции: 7.2637 секунд
#
# Дата '2024-08-06' загружена
#
# Время выполнения функции: 0.397 секунд
#
# Дата 2024-08-07 удалена из таблицы
# Время выполнения функции: 8.3354 секунд
#
# Дата '2024-08-07' загружена
#
# Время выполнения функции: 1.1279 секунд
#
# Дата 2024-08-08 удалена из таблицы
# Время выполнения функции: 6.9368 секунд
#
# Дата '2024-08-08' загружена

# %%
query = f"""SELECT 
                t1.date_week,
                t1.user_id,
                t1.profile_id,
                t1.watchtime,
                t2.trial_duration,
                t1.viewing_cnt,
                t1.viewing_watch_cnt,
                t2.reg_date,
                t2.min_date,
                t2.created_date,
                t2.first_prolong_date
                FROM 
                (SELECT * FROM datamarts.mekhtiev_watchtime_analyse_distr
                WHERE date_week BETWEEN '2024-04-01' AND '2024-07-31'
                ) AS t1
                LEFT JOIN (SELECT date_week,profile_id,trial_duration,reg_date,min_date,created_date,first_prolong_date
                           FROM  datamarts.mekhtiev_registration_distr
                           WHERE date_week BETWEEN '2024-04-01' AND '2024-07-31'
                           group by 1,2,3,4,5,6,7
                           ) AS t2
                ON t1.profile_id=t2.profile_id AND t1.date_week=t2.date_week
        """
df = execute(query,user = 'kmekhtiev')
df['date_week'] = df['date_week'].astype('datetime64[ns]')
for i in df.columns[7:]:
    df[i] = df[i].astype('datetime64[ns]')
# Out:
# Время выполнения функции: 13.1203 секунд

# %%
query="""						SELECT DISTINCT profile_id
                        FROM datamarts.marketing_dash_distr x 
                        WHERE reg_date!='1970-01-01' 
                        AND reg_date BETWEEN '2024-04-01'  AND '2024-07-31'::date
                        AND (promo_type IS NULL OR promo_type!='cards')
                        """
df_check=execute(query,user='kmekhtiev')
# Out:
# Время выполнения функции: 0.7043 секунд

# %%
df2 = df[df['reg_date']>='2024-04-01-']['profile_id'].drop_duplicates().reset_index()

df_merge = pd.merge(df_check['profile_id'],df2['profile_id'],how='left',on='profile_id',indicator='profile_type')
df_merge[df_merge.profile_type=='left_only']
# Out:
#                                  profile_id profile_type
# 7      ef07c7ce-a8b4-430a-ac1d-e0d648078aa8    left_only
# 54     b17cc4ff-d014-497c-8d80-c6793cd13321    left_only
# 135    53509e5b-9314-417e-8854-4702e4d3527d    left_only
# 157    50533eb6-c911-4927-8fb3-671e00273994    left_only
# 204    5620af5a-1bf4-4916-bff7-73894bb2f4ab    left_only
# ...                                     ...          ...
# 67963  163cad02-cf9f-4749-bcca-9d9fe88973a8    left_only
# 67965  a8233b5d-a6fb-4753-a19f-c65067cf48f3    left_only
# 67968  fed27cef-0b1d-4c6f-99d6-0917dae846db    left_only
# 67970  84119dfb-2dbb-4338-81f4-497dbe033927    left_only
# 67971  cb1af6d5-c552-4c9a-a392-3c3d7e6ba7bd    left_only
#
# [3778 rows x 2 columns]

# %%
df['dt_diff'] = (df['date_week'] - df['min_date']).dt.days
df_w_new = df[df.min_date!='1970-01-01']
df_w_new['max']= df_w_new[df_w_new.dt_diff<=6].groupby('profile_id')['dt_diff'].transform('max')
df_w_new_max = df_w_new[(df_w_new['max']==df_w_new['dt_diff']) & (df_w_new['max']<=6)]
df_w_new_max[['watchtime','viewing_cnt','viewing_watch_cnt']].describe()
# Out:
#            watchtime   viewing_cnt  viewing_watch_cnt
# count   70091.000000  70091.000000       70091.000000
# mean     1212.236464      3.378223           0.562982
# std      7679.360015      7.208056           1.698978
# min        -8.000000      0.000000           0.000000
# 25%         0.000000      0.000000           0.000000
# 50%         5.000000      1.000000           0.000000
# 75%        58.000000      3.000000           0.000000
# max    493581.000000    209.000000          52.000000

# %%
df_w_new_max[df_w_new_max.reg_date>='2024-04-01']['profile_id'].nunique()
# Out:
# 62294

# %%
df_w_new_max = df_w_new_max[df_w_new_max['reg_date']!='1970-01-01']
df_w_new_max['new_profile'] = np.where((df_w_new_max.reg_date!='1970-01-01') & (df_w_new_max.reg_date<=df_w_new_max.min_date),1,0)
df_w_new_max['new_trial'] = np.where((df_w_new_max.created_date!='1970-01-01') & (df_w_new_max.created_date<=df_w_new_max.min_date) & (df_w_new_max.trial_duration!='0'),1,0)
df_w_new_max['new_subs'] = np.where((df_w_new_max.created_date!='1970-01-01') & (df_w_new_max.first_prolong_date!='1970-01-01'),1,0)

# %%
# Определяем условия для viewing_cnt
conditions = [  
    df_w_new_max['viewing_cnt'] == 0,  
    df_w_new_max['viewing_cnt'] == 1,  
    (df_w_new_max['viewing_cnt'] > 1) & (df_w_new_max['viewing_cnt'] <= 5),  
    df_w_new_max['viewing_cnt'] > 5 
    ]  
# Определяем соответствующие значения для каждого условия  
choices = ['0', '1', '2-5', '5+']  
# Применяем np.select для создания новом столбца  
df_w_new_max['segments'] = np.select(conditions, choices, default='unknown')  



# Определяем условия для viewing_watch_cnt
conditions = [  
    df_w_new_max['viewing_watch_cnt'] == 0,  
    df_w_new_max['viewing_watch_cnt'] == 1,  
    (df_w_new_max['viewing_watch_cnt'] > 1) & (df_w_new_max['viewing_watch_cnt'] <= 5),  
    df_w_new_max['viewing_watch_cnt'] > 5 
    ]    
df_w_new_max['segments_watch'] = np.select(conditions, ['0', '1', '2-5', '5+'], default='unknown')

# %%
def grafics(segment):
    t1 = df_w_new_max.groupby(segment)['profile_id'].nunique().reset_index()
    t1.rename(columns={'profile_id': 'cnt_register'}, inplace=True)
    t1['frac_register'] = t1.cnt_register / t1.cnt_register.sum()

    t2 = df_w_new_max[df_w_new_max.new_trial == 1].groupby(segment)['profile_id'].nunique().reset_index()
    t2.rename(columns={'profile_id': 'cnt_trial'}, inplace=True)
    t2['frac_trial'] = t2.cnt_trial / t2.cnt_trial.sum()

    t1 = pd.merge(t1, t2, how='left', on=segment)
    t1['register_to_trial'] = t1.cnt_trial / t1.cnt_register
    
    t3 = df_w_new_max[df_w_new_max.new_subs == 1].groupby(segment)['profile_id'].nunique().reset_index()
    t3.rename(columns={'profile_id': 'cnt_subs'}, inplace=True)
    t3['frac_subs'] = t3.cnt_subs / t3.cnt_subs.sum()

    t1 = pd.merge(t1, t3, how='left', on=segment)
    t1['trial_to_subs'] = t1.cnt_subs / t1.cnt_trial

    # Создание графиков в виде подграфиков
    fig, axs = plt.subplots(8, 1, figsize=(25, 25))

    bars1 = axs[0].bar(t1[segment], t1['frac_register'], color=plt.cm.viridis(np.linspace(0, 1, len(t1))))
    axs[0].set_title('Доля новых зарегистрированных по сегментам')
    axs[0].set_ylabel('Доля')
    axs[0].set_xticklabels(t1[segment], rotation=45)
    axs[0].set_yticks(np.arange(0, 1.1, 0.1))
    axs[0].set_yticklabels([f'{int(i * 100)}%' for i in np.arange(0, 1.1, 0.1)])
    axs[0].grid(axis='y', linestyle='--', alpha=0.5)

    for bar in bars1:
        yval = bar.get_height()
        axs[0].text(bar.get_x() + bar.get_width() / 2, yval, f'{yval:.2%}', ha='center', va='bottom')

    bars2 = axs[1].bar(t1[segment], t1['cnt_register'], color=plt.cm.viridis(np.linspace(0, 1, len(t1))))
    axs[1].set_title('Число новых зарегистрированных по сегментам')
    axs[1].set_ylabel('Число зарегов')
    axs[1].set_xticklabels(t1[segment], rotation=45)
    axs[1].grid(axis='y', linestyle='--', alpha=0.5)

    for bar in bars2:
        yval = bar.get_height()
        axs[1].text(bar.get_x() + bar.get_width() / 2, yval, f'{yval}', ha='center', va='bottom')

    bars3 = axs[2].bar(t1[segment], t1['frac_trial'], color=plt.cm.viridis(np.linspace(0, 1, len(t1))))
    axs[2].set_title('Доля триалов по сегментам')
    axs[2].set_ylabel('Доля')
    axs[2].set_xticklabels(t1[segment], rotation=45)
    axs[2].set_yticks(np.arange(0, 1.1, 0.1))
    axs[2].set_yticklabels([f'{int(i * 100)}%' for i in np.arange(0, 1.1, 0.1)])
    axs[2].grid(axis='y', linestyle='--', alpha=0.7)

    for bar in bars3:
        yval = bar.get_height()
        axs[2].text(bar.get_x() + bar.get_width() / 2, yval, f'{yval:.2%}', ha='center', va='bottom')

    bars4 = axs[3].bar(t1[segment], t1['cnt_trial'], color=plt.cm.viridis(np.linspace(0, 1, len(t1))))
    axs[3].set_title('Число триалов по сегментам')
    axs[3].set_ylabel('Число триалов')
    axs[3].set_xticklabels(t1[segment], rotation=45)
    axs[3].grid(axis='y', linestyle='--', alpha=0.7)

    for bar in bars4:
        yval = bar.get_height()
        axs[3].text(bar.get_x() + bar.get_width() / 2, yval, f'{yval}', ha='center', va='bottom')

    bars5 = axs[4].bar(t1[segment], t1['register_to_trial'], color=plt.cm.viridis(np.linspace(0, 1, len(t1))))
    axs[4].set_title('Конверсия из регистрации в триалам по сегментам')
    axs[4].set_ylabel('Доля')
    axs[4].set_xticklabels(t1[segment], rotation=45)
    axs[4].set_yticks(np.arange(0, 1.1, 0.1))
    axs[4].set_yticklabels([f'{int(i * 100)}%' for i in np.arange(0, 1.1, 0.1)])
    axs[4].grid(axis='y', linestyle='--', alpha=0.7)

    for bar in bars5:
        yval = bar.get_height()
        axs[4].text(bar.get_x() + bar.get_width() / 2, yval, f'{yval:.2%}', ha='center', va='bottom')
        
    bars6 = axs[5].bar(t1[segment], t1['frac_subs'], color=plt.cm.viridis(np.linspace(0, 1, len(t1))))    
    axs[5].set_title('Доля подписчиков по сегментам')  
    axs[5].set_ylabel('Доля')  
    axs[5].set_xticklabels(t1[segment], rotation=45)  
    axs[5].set_yticks(np.arange(0, 1.1, 0.1), [f'{int(i * 100)}%' for i in np.arange(0, 1.1, 0.1)])  
    axs[5].grid(axis='y', linestyle='--', alpha=0.7)  

    for bar in bars6:  
            yval = bar.get_height()  
            axs[5].text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2%}', ha='center', va='bottom')  
            
    bars7 = axs[6].bar(t1[segment], t1['cnt_subs'], color=plt.cm.viridis(np.linspace(0, 1, len(t1))))    
    axs[6].set_title('Число подписчиков по сегментам')  
    axs[6].set_ylabel('Число подписчиков')  
    axs[6].set_xticklabels(t1[segment], rotation=45)  
    axs[6].grid(axis='y', linestyle='--', alpha=0.7)  
        
    for bar in bars7:  
            yval = bar.get_height()  
            axs[6].text(bar.get_x() + bar.get_width() / 2, yval, f'{yval}', ha='center', va='bottom')
    
            

    bars8 = axs[7].bar(t1[segment], t1['trial_to_subs'], color=plt.cm.viridis(np.linspace(0, 1, len(t1))))   
    axs[7].set_title('Конверсия из триала в подписку')  
    axs[7].set_ylabel('Доля')  
    axs[7].set_xticklabels(t1[segment], rotation=45)  
    axs[7].set_yticks(np.arange(0, 1.1, 0.1), [f'{int(i * 100)}%' for i in np.arange(0, 1.1, 0.1)])  
    axs[7].grid(axis='y', linestyle='--', alpha=0.7)  

    for bar in bars8:  
            yval = bar.get_height()  
            axs[7].text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2%}', ha='center', va='bottom')  

    # Увеличение расстояния между подграфиками
    plt.tight_layout()
    plt.show()

# %%
def grafics(segment):
    t1 = df_w_new_max.groupby(segment)['profile_id'].nunique().reset_index()
    t1.rename(columns={'profile_id': 'cnt_register'}, inplace=True)
    t1['frac_register'] = t1.cnt_register / t1.cnt_register.sum()

    t2 = df_w_new_max[df_w_new_max.new_trial == 1].groupby(segment)['profile_id'].nunique().reset_index()
    t2.rename(columns={'profile_id': 'cnt_trial'}, inplace=True)
    t2['frac_trial'] = t2.cnt_trial / t2.cnt_trial.sum()

    t1 = pd.merge(t1, t2, how='left', on=segment)
    t1['register_to_trial'] = t1.cnt_trial / t1.cnt_register
    
    t3 = df_w_new_max[df_w_new_max.new_subs == 1].groupby(segment)['profile_id'].nunique().reset_index()
    t3.rename(columns={'profile_id': 'cnt_subs'}, inplace=True)
    t3['frac_subs'] = t3.cnt_subs / t3.cnt_subs.sum()

    t1 = pd.merge(t1, t3, how='left', on=segment)
    t1['trial_to_subs'] = t1.cnt_subs / t1.cnt_trial

    # Создание графиков в виде подграфиков
    fig, axs = plt.subplots(5, 2, figsize=(15, 15))

    labels = t1[segment] 
    values = [t1['frac_register'][0], t1['frac_register'][1], t1['frac_register'][2],t1['frac_register'][3]]
     
    axs[0,0].pie(values, labels=labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.viridis(np.linspace(0, 1, len(t1))))  
    axs[0,0].set_title('Доля новых зарегистрированных по сегментам')  
    axs[0,0].axis('equal')  # Обеспечить, чтобы круг был кругом  

    bars2 = axs[0,1].bar(t1[segment], t1['cnt_register'], color=plt.cm.viridis(np.linspace(0, 1, len(t1))))
    axs[0,1].set_title('Число новых зарегистрированных по сегментам')
    axs[0,1].set_ylabel('Число зарегов')
    axs[0,1].set_xticklabels(t1[segment], rotation=45)
    axs[0,1].grid(axis='y', linestyle='--', alpha=0.5)

    for bar in bars2:
        yval = bar.get_height()
        axs[0,1].text(bar.get_x() + bar.get_width() / 2, yval, f'{yval}', ha='center', va='bottom')


    values2 = [t1['frac_trial'][0], t1['frac_trial'][1], t1['frac_trial'][2],t1['frac_trial'][3]]
    axs[1,0].pie(values2, labels=labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.viridis(np.linspace(0, 1, len(t1))))  
    axs[1,0].set_title('Доля новых триал по сегментам')  
    axs[1,0].axis('equal')

    bars4 = axs[1,1].bar(t1[segment], t1['cnt_trial'], color=plt.cm.viridis(np.linspace(0, 1, len(t1))))
    axs[1,1].set_title('Число триалов по сегментам')
    axs[1,1].set_ylabel('Число триалов')
    axs[1,1].set_xticklabels(t1[segment], rotation=45)
    axs[1,1].grid(axis='y', linestyle='--', alpha=0.7)

    for bar in bars4:
        yval = bar.get_height()
        axs[1,1].text(bar.get_x() + bar.get_width() / 2, yval, f'{yval}', ha='center', va='bottom')

    bars5 = axs[2,0].bar(t1[segment], t1['register_to_trial'], color=plt.cm.viridis(np.linspace(0, 1, len(t1))))
    axs[2,0].set_title('Конверсия из регистрации в триалам по сегментам')
    axs[2,0].set_ylabel('Доля')
    axs[2,0].set_xticklabels(t1[segment], rotation=45)
    axs[2,0].set_yticks(np.arange(0, 1.1, 0.1))
    axs[2,0].set_yticklabels([f'{int(i * 100)}%' for i in np.arange(0, 1.1, 0.1)])
    axs[2,0].grid(axis='y', linestyle='--', alpha=0.7)

    axs[2, 1].remove()  # Удаляем ось [2,1]

    for bar in bars5:
        yval = bar.get_height()
        axs[2,0].text(bar.get_x() + bar.get_width() / 2, yval, f'{yval:.2%}', ha='center', va='bottom')
        
    values2 = [t1['frac_subs'][0], t1['frac_subs'][1], t1['frac_subs'][2],t1['frac_subs'][3]]
    axs[3,0].pie(values2, labels=labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.viridis(np.linspace(0, 1, len(t1))))  
    axs[3,0].set_title('Доля новых подписчиков по сегментам')  
    axs[3,0].axis('equal')

    

    bars7 = axs[3,1].bar(t1[segment], t1['cnt_subs'], color=plt.cm.viridis(np.linspace(0, 1, len(t1))))    
    axs[3,1].set_title('Число подписчиков по сегментам')  
    axs[3,1].set_ylabel('Число подписчиков')  
    axs[3,1].set_xticklabels(t1[segment], rotation=45)  
    axs[3,1].grid(axis='y', linestyle='--', alpha=0.7)  
        
    for bar in bars7:  
            yval = bar.get_height()  
            axs[3,1].text(bar.get_x() + bar.get_width() / 2, yval, f'{yval}', ha='center', va='bottom')
    
            

    bars8 = axs[4,0].bar(t1[segment], t1['trial_to_subs'], color=plt.cm.viridis(np.linspace(0, 1, len(t1))))   
    axs[4,0].set_title('Конверсия из триала в подписку')  
    axs[4,0].set_ylabel('Доля')  
    axs[4,0].set_xticklabels(t1[segment], rotation=45)  
    axs[4,0].set_yticks(np.arange(0, 1.1, 0.1), [f'{int(i * 100)}%' for i in np.arange(0, 1.1, 0.1)])  
    axs[4,0].grid(axis='y', linestyle='--', alpha=0.7)  

    for bar in bars8:  
            yval = bar.get_height()  
            axs[4,0].text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2%}', ha='center', va='bottom') 
    
    axs[4, 1].remove()  # Удаляем ось [2,1]
    
    # Добавление текста между зонами
    fig.text(0.15, 1.01, 'Графики по зарегам', ha='center', va='center', fontsize=14, bbox=dict(facecolor='lightgrey', alpha=0.5))
    fig.text(0.15, 0.81, 'Графики по триалам', ha='center', va='center', fontsize=14, bbox=dict(facecolor='lightgrey', alpha=0.5))
    fig.text(0.15, 0.40, 'Графики по подписчикам', ha='center', va='center', fontsize=14, bbox=dict(facecolor='lightgrey', alpha=0.5))
 
    # Увеличение расстояния между подграфиками
    plt.tight_layout()
    plt.show()

# %%
segment='segments'
t1 = df_w_new_max.groupby(segment)['profile_id'].nunique().reset_index()
t1.rename(columns={'profile_id': 'cnt_register'}, inplace=True)
t1['frac_register'] = t1.cnt_register / t1.cnt_register.sum()

t2 = df_w_new_max[df_w_new_max.new_trial == 1].groupby(segment)['profile_id'].nunique().reset_index()
t2.rename(columns={'profile_id': 'cnt_trial'}, inplace=True)
t2['frac_trial'] = t2.cnt_trial / t2.cnt_trial.sum()


labels = t1[segment] 
sizes = t1['frac_register']

values = [t1['frac_register'][0], t1['frac_register'][1], t1['frac_register'][2],t1['frac_register'][3]]

values
# Out:
# [0.44927446838039137,
#  0.1779055960770405,
#  0.22148375456830482,
#  0.1513361809742633]

# %%
grafics('segments')

# %% [markdown]
# ## 1.Гипотеза
#
# 1. **Анализ новых пользователей** с разбивкой по сегментам просмотра:
#    - 0 видео просмотрено
#    - 1 видео просмотрено
#    - 2-5 видео просмотрено
#    - 5+ видео просмотрено
#
# ### Цель исследования
# Выяснить, какие паттерны поведения демонстрируют новые пользователи в зависимости от количества видео,которые были показаны, и на основании этих данных улучшить онбординг для новых пользователей.
#
# ### Определения
#
# - **Новый пользователь**: пользователь, который впервые зашел в приложение и зарегистрировался в течение 1 недели после первого посещения.
# - **Период анализа**: с 01.04.2024 по 01.08.2024.
# - **Типы видео**: все форматы видео (тв, фильмы, сериалы, киномы).
# - **Просмотр**: считается смотрение, если пользователь смотрел хотя бы один тайтл более **30 секунд** в течение недели.
#
# ## Методология
#
# Анализ будет проводиться по двум основным срезам:
#
# 1. **По сегментам просмотра**:
#    - Все новые пользователи с разбивкой по количеству видео смотрения: **0, 1, 2-5, 5+**.
#
# 2. **По покупке**:
#    - Все новые пользователи с разбивкой по количеству просмотренных видео: **0, 1, 2-5, 5+**.

# %%
grafics('segments')

# %%
def trial_type(segment):
        df_trial = df_w_new_max[(df_w_new_max['new_trial']==1) & (df_w_new_max['trial_duration'].isin(['3','14','30','35','45']))].groupby([segment,'trial_duration'])['profile_id'].nunique().reset_index()
        df_trial['sum'] = df_trial.groupby(segment)['profile_id'].transform('sum')
        df_trial['frac_trial'] = df_trial['profile_id']/df_trial['sum']



        plt.figure(figsize=(20, 8))  # Устанавливаем размер фигуры  

        # Строим barplot с использованием Seaborn  
        sns.barplot(data=df_trial, x=segment, y='frac_trial', hue='trial_duration', ci=None)  

        # Настраиваем заголовок и метки  
        plt.title('Сегменты в разбивке по длительности триалов')  
        plt.xlabel('Сегменты')  
        plt.ylabel('Доля')  
        plt.legend(title='Триалы')  
        plt.xticks(rotation=45)
        plt.yticks(np.arange(0, 1.1, 0.1), [f'{int(i * 100)}%' for i in np.arange(0, 1.1, 0.1)])  

        # Отображаем график  
        plt.tight_layout()  
        plt.show()

# %%
trial_type('segments')

# %%
trial_type('segments_watch')

# %%
list_date = pd.date_range("2024-04-01", "2024-07-31", freq='MS',normalize=True)
result = []
for date in list_date:
    date_str = date.strftime('%Y-%m-%d')
    query = f'''
            SELECT 
                '{date_str}' AS date_month,
                paid_at::date AS paid_date,
                s.user_id AS user_id,
                i.subscription_id AS subscription_id,
                s.created_at::date AS created_date,
                sum(i.price_cents)/100 AS payment
                FROM  product_x.invoices i
                LEFT JOIN product_x.subscriptions s
                ON s.id = i.subscription_id
                LEFT JOIN product_x.users u 
                ON u.id = s.user_id
                WHERE u.user_type = 'regular'
                      AND u.vipplay = FALSE
                      AND s.state in ('normal_period','trial','canceled','grace_period')
                      AND DATE_TRUNC('month', paid_at::date)='{date_str}'
                      AND i.state in ('success')
                      AND i.price_cents > 100
                      AND i.price_currency = 'RUB'
                GROUP BY 1,2,3,4,5
            '''
    df_temp = execute(query,user = 'kmekhtiev')   
    result.append(df_temp)
    print(f"""Дата '{date_str}' загружена""")
    print()

df_payment = pd.concat(result)
df_payment['paid_date'] = df_payment['paid_date'].astype('datetime64[ns]')
df_payment['payment'] = df_payment['payment'].astype('int32')
# Out:
# Время выполнения функции: 26.5324 секунд
#
# Дата '2024-04-01' загружена
#
# Время выполнения функции: 14.9872 секунд
#
# Дата '2024-05-01' загружена
#
# Время выполнения функции: 5.0171 секунд
#
# Дата '2024-06-01' загружена
#
# Время выполнения функции: 4.6083 секунд
#
# Дата '2024-07-01' загружена

# %%
df_payment.groupby('date_month').agg({'payment':'sum','subscription_id':'nunique'}).reset_index()
# Out:
#    date_month  payment  subscription_id
# 0  2024-04-01   988639             2787
# 1  2024-05-01  1074662             2935
# 2  2024-06-01  1109673             3070
# 3  2024-07-01   998644             3160

# %%
df_payment_agg = df_payment.groupby('user_id').agg({'payment':'sum','subscription_id':'count'}).reset_index()

df_payment2 = pd.merge(df_payment_agg,df_w_new_max[['user_id','segments','segments_watch','created_date']],on='user_id',how='left')
df_pay2 = pd.merge(df_payment,df_w_new_max[['user_id','segments','segments_watch','created_date']],on='user_id',how='inner')


df_payment2_agg_segments = df_payment2[df_payment2.created_date.notna()].groupby('segments').agg({'user_id':'nunique','payment':'sum','subscription_id':'sum'}).reset_index()
df_payment2_agg_segments_watch = df_payment2[df_payment2.created_date.notna()].groupby('segments_watch').agg({'user_id':'nunique','payment':'sum','subscription_id':'sum'}).reset_index()

df_payment2_agg_segments['ARPPU'] = df_payment2_agg_segments.payment / df_payment2_agg_segments.user_id
df_payment2_agg_segments['AOV'] = df_payment2_agg_segments.payment / df_payment2_agg_segments.subscription_id
df_payment2_agg_segments



fig, axs = plt.subplots(2, 1, figsize=(13, 7))  

# Построение первого графика (AOV)  
bar1 = axs[0].bar(df_payment2_agg_segments['segments'], df_payment2_agg_segments['AOV'],  color=plt.cm.viridis(np.linspace(0, 1, len(t1))))  
axs[0].set_title('Средний чек (AOV)')   
axs[0].set_ylabel('Руб')  
axs[0].tick_params(axis='x', rotation=45)  # Вращение меток по оси X для лучшей читаемости  

# Построение второго графика (ARPPU)  
bar2 = axs[1].bar(df_payment2_agg_segments['segments'], df_payment2_agg_segments['ARPPU'],  color=plt.cm.viridis(np.linspace(0, 1, len(t1))))  
axs[1].set_title('ARPPU')   
axs[1].set_ylabel('Руб')  
axs[1].tick_params(axis='x', rotation=45)  # Вращение меток по оси X для лучшей читаемости  

for bar in bar1:  
        yval = bar.get_height()  
        axs[0].text(bar.get_x() + bar.get_width() / 2, yval, f'{int(round(yval))}', ha='center', va='bottom')

for bar in bar2:  
        yval = bar.get_height()  
        axs[1].text(bar.get_x() + bar.get_width() / 2, yval, f'{int(round(yval))}', ha='center', va='bottom')        
            
# Настройка компоновки  
plt.tight_layout()  
plt.show()

# %%
df_payment2_agg_segments_watch['ARPPU'] = df_payment2_agg_segments_watch.payment / df_payment2_agg_segments_watch.user_id
df_payment2_agg_segments_watch['AOV'] = df_payment2_agg_segments_watch.payment / df_payment2_agg_segments_watch.subscription_id


fig, axs = plt.subplots(2, 1, figsize=(13, 7))  

# Построение первого графика (AOV)  
bar1 = axs[0].bar(df_payment2_agg_segments_watch['segments_watch'], df_payment2_agg_segments_watch['AOV'],  color=plt.cm.viridis(np.linspace(0, 1, len(t1))))  
axs[0].set_title('Средний чек (AOV)')   
axs[0].set_ylabel('Руб')  
axs[0].tick_params(axis='x', rotation=45) 

# Построение второго графика (ARPPU)  
bar2 = axs[1].bar(df_payment2_agg_segments_watch['segments_watch'], df_payment2_agg_segments_watch['ARPPU'],  color=plt.cm.viridis(np.linspace(0, 1, len(t1))))  
axs[1].set_title('ARPPU')   
axs[1].set_ylabel('Руб')  
axs[1].tick_params(axis='x', rotation=45)

for bar in bar1:  
        yval = bar.get_height()  
        axs[0].text(bar.get_x() + bar.get_width() / 2, yval, f'{int(round(yval))}', ha='center', va='bottom')

for bar in bar2:  
        yval = bar.get_height()  
        axs[1].text(bar.get_x() + bar.get_width() / 2, yval, f'{int(round(yval))}', ha='center', va='bottom')        
            
# Настройка компоновки  
plt.tight_layout()  
plt.show()

# %%
         # Рассчитываем средневзвешенное значение LTV для каждого 'num_of_month'
def calculate_weighted_avg_ltv(df_segment):
    segment_name = df_segment.name
    segment_weighted_ltv = (df_segment * user_counts.loc[(slice(None), segment_name), :]).sum() / user_counts.loc[(slice(None), segment_name), :].sum()
    return segment_weighted_ltv

# Создание данных
def ltv(df_pay2,segment):
    df_pay2['paid_month'] = df_pay2['paid_date'].dt.to_period('M')
    df_pay2 = df_pay2.sort_values(by=[segment,'date_month','paid_month'])
    df_ltv = df_pay2.groupby(['date_month', 'paid_month', segment]).agg({'payment': 'sum', 'user_id': 'count'}).reset_index()

        # Расчет кумулятивной суммы и добавления поля по числу пользователей когорты 
    df_ltv = df_ltv.sort_values(by=['date_month', segment, 'paid_month'])
    df_ltv['cumulative'] = df_ltv.groupby([segment])['payment'].cumsum()
    df_ltv['uniq_user'] = df_ltv.groupby([segment])['user_id'].transform('max')

        # # Расчет ltv
    df_ltv['ltv'] = df_ltv.cumulative / df_ltv.uniq_user

        # # Нумерация месяцев
    df_ltv['num_of_month'] = df_ltv.groupby([segment])['paid_month'].rank(method='first').astype('int')

        # Сделаем pivot
    df_pivot = df_ltv.pivot_table(index=['date_month', segment], columns='num_of_month', values='ltv')
    df_pivot['uniq_user'] = df_ltv.groupby(['date_month', segment])['uniq_user'].max()

        # Создаем DataFrame с данными для расчета средневзвешенного LTV
    weighted_ltv = df_ltv.pivot_table(index=['date_month', segment], columns='num_of_month', values='ltv')
    user_counts = df_ltv.pivot_table(index=['date_month', segment], columns='num_of_month', values='uniq_user')


    weighted_avg_ltv = weighted_ltv.groupby(level=segment).apply(calculate_weighted_avg_ltv)

        # Преобразуем в DataFrame
    weighted_avg_ltv = weighted_avg_ltv.reset_index()
    weighted_avg_ltv = weighted_avg_ltv.rename(columns={0: 'cumsum'})

        #Сначала преобразуем датафрейм в длинный формат с помощью melt
    melted_df = pd.melt(weighted_avg_ltv, id_vars=[segment], var_name='num_of_month', value_name='value')

        # Теперь преобразуем его в требуемый формат с помощью pivot
    pivot_df = melted_df.pivot(index='num_of_month', columns=segment, values='value').reset_index()
        
        
    plt.figure(figsize=(30,10))

        # Построение линий для каждого сегмента
    for i in pivot_df.columns[1:]:
        plt.plot(pivot_df.num_of_month, pivot_df[i], marker='o', linestyle='-', label=i)

    plt.xlabel('Месяцы')
    plt.ylabel('Руб')
    plt.title('Изменение LTV по месяцам')
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.legend(title='Segments')
    plt.show()

# %%
pivot_df.columns[1:]
# Out:
# Index(['0', '1', '2-5', '5+'], dtype='object', name='segments')

# %%
ltv(df_pay2,'segments_watch')

# %%
query = """
    SELECT 
        count(DISTINCT CASE WHEN email IS NOT NULL AND phone_number IS NULL THEN profile_id END) cnt_email,
        count(DISTINCT CASE WHEN phone_number IS NOT NULL AND email IS NULL THEN profile_id END) cnt_phone,
        count(DISTINCT CASE WHEN phone_number IS NOT NULL AND email IS NOT NULL THEN profile_id end) cnt_both
        FROM 
        (SELECT t1.profile_id,t2.email,t2.phone_number
        FROM 
        (SELECT DISTINCT profile_id 
        FROM datamarts.mekhtiev_registration_distr
        WHERE created_date::date BETWEEN '2024-04-01' AND '2024-08-01'
        )AS t1

        LEFT JOIN (SELECT profile_id,email,phone_number
                    FROM datamarts.dash_table_distr AS t1
                    LEFT JOIN product_x.users  AS t2
                    ON t1.user_id=t2.id
                    WHERE created_at::date BETWEEN '2024-04-01' AND '2024-08-01'
                    AND email IS NOT NULL OR phone_number IS NOT NULL 
                    GROUP BY 1,2,3
                    ) AS t2
        ON t1.profile_id=t2.profile_id)
        """

df_email = execute(query,user='kmekhtiev')
# Out:
# Время выполнения функции: 3.4799 секунд

# %%
df_email
# Out:
#    cnt_email  cnt_phone  cnt_both
# 0       9542      11637       742

# %%
# Подготовка данных для графиков  
labels = ['Почта', 'Номер', 'Номер/почта']  
values = [df_email['cnt_email'][0], df_email['cnt_phone'][0], df_email['cnt_both'][0]]  

# Настройка общего размера графиков  
fig, axs = plt.subplots(1, 2, figsize=(16, 6))  

# Построение столбчатой диаграммы  
bars = axs[0].bar(labels, values, color=['blue', 'orange', 'green'])  
axs[0].set_title('Число пользователей по каждому полю')  
axs[0].set_ylabel('Количество пользователей')  

for bar in bars:  
    yval = bar.get_height()  
    axs[0].text(bar.get_x() + bar.get_width()/2, yval, int(yval),   
                 ha='center', va='bottom')  # 'ha' - горизонтальное выравнивание, 'va' - вертикальное  


# Построение круговой диаграммы  
axs[1].pie(values, labels=labels, autopct='%1.1f%%', startangle=90)  
axs[1].set_title('Доля пользователей')  

# Упорядочивание круговой диаграммы  
axs[1].axis('equal')  # Обеспечить, чтобы круг был кругом  

# Показать графики  
plt.tight_layout()  
plt.show()
